# %% [markdown]
# ### 전국로컬푸드인증
# - csv 파일 수동 다운로드하여 작업
# - ndarray 사용가능 (문자열 데이터 타입)
#
# * 인기품목 top 10 (품목명 카운트)
# * dictionary -> {군단위지역명 : [품목명]}
# * dictionary -> {품목명 : [군단위지역명]}
# * csvfile -> 전국로컬푸드인증정보표준데이터.csv
# * 파일명 : 이름_localfood

# %%
import numpy as np
import re

def my_split(s):
    block_start = False
    start_index = 0
    ret_list=[]
    for i, c in enumerate(s):
        if block_start==False:
            if c==',':
                ret_list.append(s[start_index:i])
                start_index=i+1
            elif c=='"':
                block_start=True
                start_index = i
        else:
            if c=='"':
                block_start=False
    if s[-1]!=',':
        ret_list.append(s[start_index:])
    return ret_list

# %%
csv_data = []
with open('전국로컬푸드인증정보표준데이터.csv') as f:
    for line in f:
        csv_data.append(my_split(line))

itemIndex = csv_data[0].index('품목명')
localIndex = csv_data[0].index('관리기관명')
item_pass1 = []
local_pass1 = []
for i in csv_data[1:]:
    item_pass1.append(i[itemIndex].replace('"','').replace('(',',').replace(')','').replace(',','+').split('+'))
    local_pass1.append(i[localIndex])
for i in item_pass1:
    for e , s in enumerate(i):
        i[e] = s.strip()
        if '외' in s and '참외' not in s:
            i[e] = re.sub(r'[0-9]|외|품목','',s)

    
item_pass2 = []
for i in item_pass1:
    for e, s in enumerate(i):
        item_pass2.append(i[e])

# %%
item_set = set(item_pass2)
item_count = []
for i in item_set:
    item_count.append(item_pass2.count(i))

item_di = dict(zip(item_set,item_count))
item_di = sorted(item_di.items(), key  = lambda x:x[1], reverse = True)
print(item_di[:10])
# Out:
# [('고추', 1398), ('콩', 632), ('배추', 580), ('고구마', 577), ('대파', 566), ('호박', 553), ('감자', 544), ('상추', 540), ('무', 513), ('마늘', 437)]

# %%
address_item = {}
for i, address in enumerate(local_pass1):
    if address not in address_item:
        address_item[address] = [item_pass2[i]]
    else:
        address_item[address].append(item_pass2[i])
print(address_item)
# Out:
# {'경상남도 함양군청': ['칡청', '달맞이꽃씨유', '굼벵이환', '메론', '차요태', '열매마', '포도', '꿀', '포도', '사과', '샤인머스켓', '미숫가루', '밀가루', '쌀', '사과', '알밤', '한라봉', '레드향', '천혜향', '사과', '서복태', '함양애주', '지리산애주', '키고리', '스카프', '가방', '두건', '로메인 상추', '더덕주', '블루베리', '호두', '새싹인삼', '유정란', '한과', '도라지', '곶감', '감말랭이', '딸기', '고로쇠 수액', '지리산도라지와돌배', '곶감', '말랭이', '사과', '딸기', '복수박', '두릅', '고사리', '취나물', '누른호박', '배', '즙류', 'ABC주스', '우슬진액', '꿀류', '차류', '미나리', '두릅', '취나물', '머위즙', '블루베리', '신령호두', '부각류', '블루베리', '가지', '애호박', '사과', '차류', '아스파라거스', '담솔', '복분자', '솔송주', '고구마', '사과', '도마', '주걱', '약초류', '유기농계란', '엉겅퀴', '오가피', '죽염류', '된장', '치약', '국화분재', '표고버섯', '도라지', '부각류', '옥수수', '그린하미과', '컬리플라워', '생강청', '산골편강', '도라비배청', '보리새싹', '레몬머틀', '배', '고구마', '오란다', '조청산자', '김부각', '강정류', '꿀류', '곶감', '대파', '양상추', '곶감', '사과', '감자', '고구마', '쪽파', '대파', '고추', '무', '배추', '아스파라거스', '검정깨', '참깨', '쌀', '건토란잎', '토란줄기', '건토란줄기', '가죽나물', '건가죽나물', '우엉', '건우엉', '단감', '차랑', '감', '대봉', '감', '대봉홍시', '복숭아', '복숭아', '백도', '복숭아', '황도', '살구', '자두', '플럼코트', '티파니', '고구마', '호박', '돼지감자', '옥수수', '초당', '박', '토란', '깐토란', '무', '토란', '냉이', '도라지', '머위순', '머윗대', '비비추', '쑥부쟁이', '토란줄기', '삶은토란줄기', '토란잎', '삶은토란잎', '배추', '배추', '쌈배추', '배추', '얼갈이배추', '부추', '상추', '열무', '대파', '밤', '깨', '참깨', '복숭아', '못난이', '플럼코트', '하모니', '플럼코트', '심포니', '플럼코트', '샤이니', '오이', '백다다기', '오이', '취청', '기획행사_가공식품', '이반촌 똘배초', '이반촌 산돌배즙', '이반촌 건돌배', '이반촌똘배초세트', '키위', '그린:숙성과', '머윗대', '명이나물', '방앗잎', '쑥', '엄나무순', '질경이'], '경기도 화성시청': ['삼백초즙', '사과즙', '오미자청', '도라지배즙', '고구마', '무말랭이', '시래기', '사과', '사과즙', '반쯤깐밤', '산삼캔디', '지리산명월초 티백차', '표고버섯', '우산고로쇠 수액', '본래족발스페셜세트', '이불', '베개', '목화솜', '꾸찌봉차', '꾸지뽕진액', '오미자즙', '양파즙', '매실원액', '개복숭아원액', '솔순원액', '고로쇠 수액', '달걀', '꿀', '화분', '아스파라거스', '꿀류', '고구마', '산삼캔디', '산삼젤리', '곡물강정', '산삼견과정', '오미자랑', '고추부각', '김부각', '고추장', '된장', '간장', '사과', '국수', '마스크팩', '샴푸', '산삼주', '무말랭이', '아주까리잎', '토마토', '열매마', '지리산 배도라지 생강청', '백봉령', '도라지', '산머루즙골드', '블루베리진액', '상황버섯진액', '하늘과맞닿은 사과즙 도라지배즙', '냉동산딸기', '적양파', '양파', '감자', '수박', '지리산 꾸찌봉잎차', '산딸기', '마늘', '열무', '양파', '치커리', '상추', '열무', '배추', '호박', '대파', '호박잎', '마늘', '고추', '고추', '마늘', '마늘', '양파', '포도', '블루베리', '블루베리', '복숭아', '토종빨강강낭콩', '고추', '새송이', '감자', '완두', '살구', '복숭아', '당근', '노각오이', '바이오체리', '사과대추', '들깻잎', '참외', '토마토', '호박', '오이', '고추', '대파', '대파', '메리골드', '블루베리', '참외', '고추', '들깻잎', '포도', '가리비', '굴', '옥수수', '포도', '포도', '개구리참외', '복수박', '사과참외', '들깻잎', '고추', '딸기', '토마토', '오이', '목이', '아스파라거스', '아스파라거스', '표고', '체리', '아스파라거스', '표고', '감자', '감자', '고구마', '감자', '마늘', '토마토', '방울토마토', '양파', '감자', '블루베리', '블루베리', '오디', '오디', '마늘', '마늘', '양파', '고수', '홍감자', '감자', '블루베리', '감자', '감자', '감자', '감자', '감자', '고구마', '완두', '완두', '완두', '잠두', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '딸기', '아스파라거스', '열무', '표고', '딸기', '오이', '목이', '시금치', '상추', '오이', '상추', '양상추', '양배추', '아스파라거스', '딸기', '아스파라거스', '표고', '표고', '목이', '아스파라거스', '토종근대', '토종아욱', '돌미나리 등', '표고', '목이', '표고', '감자', '들깨', '참깨', '서리태', '콩나물콩', '딸기', '딸기', '딸기', '딸기', '상추', '토마토', '오이', '딸기', '감자', '감자', '상추', '딸기', '딸기', '느타리', '딸기', '오이', '호박', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '들깻잎', '무', '배추', '알타리', '만차랑단호박', '고추', '무', '배추', '들깨', '무', '배추', '토마토', '들깨', '딸기', '딸기', '딸기', '딸기', '딸기', '딸기', '딸기', '딸기', '딸기', '수수', '수수', '대두', '고구마', '배', '토란대', '고추', '무', '배추', '고추', '무', '배추', '알타리', '고추', '무', '고추', '무', '배추', '쪽파', '고구마', '돼지감자', '고구마', '대파', '배추', '갓', '당근', '울금', '대파', '딸기', '배추', '냉이', '시금치', '무', '부추', '무', '무', '가지', '대파', '대파', '쌈채소', '생강', '달래', '딸기', '들깨', '배추', '애호박', '울금', '대파', '울금', '부추', '배추', '배추', '고구마', '대파', '무', '우엉', '시금치', '배추', '강황', '무', '무', '딸기', '딸기', '블루베리', '단감', '감귤', '사과', '사과', '사과', '부추', '부추', '토마토', '배추', '고구마', '배추', '배추', '배추'], '충청남도 서산시청': ['대두', '쥐눈이콩', '팥', '서리태', '푸른콩', '서리태', '작두콩', '서리태', '대추', '딸기', '딸기', '딸기', '딸기', '딸기', '배추', '무', '배추', '배추', '들깨', '고구마', '고구마', '사과', '고추', '무', '배추', '무', '머위', '얼갈이배추', '대파', '고추 등', '대파', '부추', '배추', '무', '호박 등', '고추', '양배추', '더덕', '찹쌀', '감자', '녹두', '대두', '팥', '은행', '배추', '고추' ...

# %%
item_pass2 = set(item_pass2)
item_address = {}
for i, item in enumerate(item_pass2):
    if item not in item_address:
        item_address[item] = [local_pass1[i]]
    else:
        item_address[item].append(local_pass1[i])
print(item_address)
# Out:
# {'': ['경상남도 함양군청'], '자색돼지감자차': ['경상남도 함양군청'], '비트분말_데일리파머스백': ['경상남도 함양군청'], '건비트': ['경상남도 함양군청'], '활암꽃게': ['경상남도 함양군청'], '메주-서당골': ['경상남도 함양군청'], '찹쌀 ': ['경상남도 함양군청'], '우리밀수제비': ['경상남도 함양군청'], '염좌': ['경상남도 함양군청'], '청포도': ['경상남도 함양군청'], 'C카갈대쿠키': ['경상남도 함양군청'], '메주-송광': ['경상남도 함양군청'], '큰둥근마': ['경상남도 함양군청'], '돼지목등심불고기': ['경상남도 함양군청'], '매실현미뻥스낵': ['경상남도 함양군청'], '솔순엑기스': ['경상남도 함양군청'], '돌미나리': ['경상남도 함양군청'], '깨': ['경상남도 함양군청'], '멜론키위잼_순순순': ['경상남도 함양군청'], '소포라': ['경상남도 함양군청'], '천연다시팩': ['경상남도 함양군청'], '대부도재래김': ['경상남도 함양군청'], '모기퇴치제': ['경상남도 함양군청'], '건우슬': ['경상남도 함양군청'], '소세지빵': ['경상남도 함양군청'], '돼지항정살': ['경상남도 함양군청'], '고야': ['경상남도 함양군청'], '청산도쌈다시마_아라온': ['경상남도 함양군청'], '두부': ['경상남도 함양군청'], '옥수수심': ['경상남도 함양군청'], '콩비지분말-송광': ['경상남도 함양군청'], '땅콩호박': ['경상남도 함양군청'], '맹감뿌리': ['경상남도 함양군청'], '불미나리': ['경상남도 함양군청'], '중': ['경상남도 함양군청'], '오가피나무': ['경상남도 함양군청'], '박고지': ['경상남도 함양군청'], '방물토마토': ['경상남도 함양군청'], '80g': ['경상남도 함양군청'], 'C카감말랭이': ['경상남도 함양군청'], '꿀비누': ['경상남도 함양군청'], 'C여콩': ['경상남도 함양군청'], '청산도건세모가사리_아라온': ['경상남도 함양군청'], '참한솔된장': ['경상남도 함양군청'], '건고구마순': ['경상남도 함양군청'], '냉동아귀꼬리살': ['경상남도 함양군청'], '양념LA갈비': ['경상남도 함양군청'], '순천만함초진액': ['경상남도 함양군청'], '향미': ['경상남도 함양군청'], '네모난당면': ['경상남도 함양군청'], '청배추': ['경상남도 함양군청'], '감자 ': ['경상남도 함양군청'], '먹단감': ['경상남도 함양군청'], '흰민들레': ['경상남도 함양군청'], '약감': ['경상남도 함양군청'], '시트리나': ['경상남도 함양군청'], '편백캠핑도마': ['경상남도 함양군청'], '아로니아환-늘솔길': ['경상남도 함양군청'], '청양고추-장아찌용': ['경상남도 함양군청'], '토란대': ['경기도 화성시청'], '두릅순': ['경상남도 함양군청'], '맘모스': ['경상남도 함양군청'], '연근가루': ['경상남도 함양군청'], '오디  ': ['경상남도 함양군청'], '히카마': ['경상남도 함양군청'], '편백베개': ['경상남도 함양군청'], '토복령': ['경상남도 함양군청'], '오이소박이': ['경상남도 함양군청'], '전통찹쌀고추장': ['경상남도 함양군청'], '우리농민유채유': ['경상남도 함양군청'], '개망초 나물': ['경상남도 함양군청'], '미나리쿠키': ['경상남도 함양군청'], '지리산명월초 티백차': ['경상남도 함양군청'], '전통주류': ['경상남도 함양군청'], '유과': ['경상남도 함양군청'], '밤나물': ['경상남도 함양군청'], '표고': ['경상남도 함양군청'], '마디호박': ['경상남도 함양군청'], '새꼬막': ['경상남도 함양군청'], '신고10과': ['경상남도 함양군청'], '흰강낭콩': ['경상남도 함양군청'], '가천산방겨우살이차': ['경상남도 함양군청'], '두충': ['경상남도 함양군청'], '옥수수속대': ['경상남도 함양군청'], '우리밀자장라면': ['경상남도 함양군청'], '미니오이': ['경상남도 함양군청'], '화초양귀비': ['경상남도 함양군청'], '순꽃함초환': ['경상남도 함양군청'], 'C반함초멸치액젓': ['경상남도 함양군청'], '블루베리방울유과_쌍지뜰': ['경상남도 함양군청'], '가지고추': ['경상남도 함양군청'], '순모링가분말_순순순': ['경상남도 함양군청'], '월하시': ['경상남도 함양군청'], '대부도김도시락김': ['경상남도 함양군청'], '연근분말': ['경상남도 함양군청'], '유채': ['경상남도 함양군청'], '미강': ['경상남도 함양군청'], '감국': ['경상남도 함양군청'], '순천만울금환_덕동원': ['경상남도 함양군청'], '조미': ['경상남도 함양군청'], '순천만함초자염350g*2': ['경상남도 함양군청'], '리나리아': ['경상남도 함양군청'], '차류선물세트_모던팜': ['경상남도 함양군청'], '홍차-모후실': ['경상남도 함양군청'], '돼지냉동대패삼겹살': ['경상남도 함양군청'], '볶은죽순차': ['경상남도 함양군청'], '순천만갈대김부각': ['경상남도 함양군청'], '선어세트': ['경기도 화성시청'], '금화규': ['경기도 화성시청'], '칠게': ['경기도 화성시청'], '얼갈이배추': ['경기도 화성시청'], '토종배추': ['경기도 화성시청'], '찰조': ['경기도 화성시청'], '재래종': ['경기도 화성시청'], '배말랭이': ['경기도 화성시청'], '강황환': ['경기도 화성시청'], '로얄제리': ['경기도 화성시청'], '손당면': ['경기도 화성시청'], '마가렛': ['경기도 화성시청'], '천연염색커버': ['경기도 화성시청'], '갈대김부각선물세트_자연맛길': ['경기도 화성시청'], '2종': ['경기도 화성시청'], '홍주씨드리스  ': ['경기도 화성시청'], '상황가족': ['경기도 화성시청'], '산머루': ['경기도 화성시청'], '단풍마': ['경기도 화성시청'], '초록무': ['경기도 화성시청'], '히말리아등불': ['경기도 화성시청'], '해조류세트2호_아라온': ['경기도 화성시청'], '목이': ['경기도 화성시청'], '참다래': ['경기도 화성시청'], '표고버섯  ': ['경기도 화성시청'], '자색무': ['경기도 화성시청'], '청산도곱창김_아라온': ['경기도 화성시청'], '노고치매실고추장장아찌': ['경기도 화성시청'], '무릎담요': ['경기도 화성시청'], '방울토마토  ': ['경기도 화성시청'], '황궁채': ['경기도 화성시청'], '대보-특대': ['경기도 화성시청'], '사과즙': ['경기도 화성시청'], '새싹삼누룽지': ['경기도 화성시청'], '아로니아분말-순순순': ['경기도 화성시청'], '한우사골곰탕': ['경기도 화성시청'], '샤인머스켓  ': ['경기도 화성시청'], '적양배추': ['경기도 화성시청'], '비파': ['경기도 화성시청'], '가마솥고향수제누룽지_순천만누룽지': ['경기도 화성시청'], '묘목': ['경기도 화성시청'], '옻나무순': ['경기도 화성시청'], '카틀레야': ['경기도 화성시청'], '원목': ['경기도 화성시청'], 'C여깐토란': ['경기도 화성시청'], '오색떡국떡': ['경기도 화성시청'], '공심채': ['경기도 화성시청'], '머위꽃': ['경기도 화성시청'], '깐완두': ['경기도 화성시청'], '표고분말': ['경기도 화성시청'], '콩류': ['경기도 화성시청'], '지리산흑돼지 찌개용 500G': ['경기도 화성시청'], '매실엑기스': ['경기도 화성시청'], '미역귀': ['경기도 화성시청'], '돼지전지찌개용': ['경기도 화성시청'], '유레카목장스트링치즈': ['경기도 화성시청'], '벌꿀': ['경기도 화성시청'], '한솔분말청국장': ['경기도 화성시청'], '고추 등': ['경기도 화성시청'], '리틀잼': ['경기도 화성시청'], '아삭이상추': ['경기도 화성시청'], '건감잎': ['경기도 화성시청'], ' ...
